# %%
import pandas as pd
data_dir = "data/"

# %%
cv_results_ex_1 = pd.read_csv(data_dir + "cv_results_mb_gen_seed_reset_v1.csv")
cv_results_ex_2 = pd.read_csv(data_dir + "cv_results_mb_gen_seed_reset_v2.csv")

cv_results_ex_1.sort_values("mean_test_AU_PRC", inplace=True, ascending=False)
cv_results_ex_2.sort_values("mean_test_AU_PRC", inplace=True, ascending=False)

# %%
cv_results_ex_2.head()
# Out:
#     negative_perc  np_ratio  positive_sample_perc  mean_test_AU_PRC  \
# 7            0.25       1.0                  0.50          0.613024
# 3            0.25       0.5                  1.00          0.595248
# 5            0.25       0.5                  1.50          0.560847
# 35           0.50       0.5                  1.50          0.559969
# 34           0.50       0.5                  1.25          0.544376
#
#     mean_train_AU_PRC  mean_test_AU_ROC  mean_train_AU_ROC  \
# 7            0.040265          0.981225           0.989448
# 3            0.039869          0.981560           0.989453
# 5            0.033944          0.980873           0.987271
# 35           0.040381          0.977555           0.987919
# 34           0.042322          0.979593           0.990712
#
#     mean_test_AVG_PREC  mean_train_AVG_PREC  std_test_AU_PRC  \
# 7             0.615447             0.040831         0.056462
# 3             0.600855             0.040326         0.029459
# ...

# %%
cv_results_ex_1.head()
# Out:
#     negative_perc  np_ratio  positive_sample_perc  mean_test_AU_PRC  \
# 33           0.50       0.5                  1.00          0.635461
# 34           0.50       0.5                  1.25          0.623804
# 40           0.50       1.0                  1.25          0.582827
# 9            0.25       1.0                  1.00          0.574001
# 3            0.25       0.5                  1.00          0.571243
#
#     mean_train_AU_PRC  mean_test_AU_ROC  mean_train_AU_ROC  \
# 33           0.044435          0.984436           0.990521
# 34           0.037640          0.979172           0.990145
# 40           0.035686          0.977045           0.986571
# 9            0.034636          0.982919           0.988264
# 3            0.045381          0.980162           0.989401
#
#     mean_test_AVG_PREC  mean_train_AVG_PREC  std_test_AU_PRC  \
# 33            0.641657             0.045251         0.096024
# 34            0.626092             0.038037         0.064513
# ...
